# %% [markdown]
# # Data Analyst Professional Practical Exam Submission
#
# **You can use any tool that you want to do your analysis and create visualizations. Use this template to write up your summary for submission.**
#
# You can use any markdown formatting you wish. If you are not familiar with Markdown, read the [Markdown Guide](https://s3.amazonaws.com/talent-assets.datacamp.com/Markdown+Guide.pdf) before you start.

# %% [markdown]
# ## 📝 Task List
#
# Your written report should include written text summaries and graphics of the following:
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
#
#
#
#
#
#
# ###Product Sales Report
#
# ##Data Validation
# 'week': 15000 entries all non-null integers. No change needed.
#
# 'sales_method': 15000 entries all non-null objects. Should be only 3 categories but are 5. Corrected typos for 'email', and 'em + call'.
#
# 'customer_id': 15000 entries all non-null unique objects. No change needed.
#
# 'nb_sold': 15000 entries all non-null integers. No change needed.
#
# 'revenue': 13926 entires, remainder missing values. I thought about imputing the average price per 'nb_sold', however, the spread between price ranges was too large. Since NA's only accounted for less than 10% of the data, I dropped the missing rows from the data set.
#
# 'years_as_customer': all non-null integers. No change needed.
#
# 'nb_site_visits': all non-null integers. No change needed
#
# 'state': all non-null objects. No change needed
#
#
# ##Exploratory Analysis
#
# Looking at total sales by sales method, we can see Email was the most successful with about 7k total sales, followed by Calls at around 5k and last was both at about 2k.
#
# ![Figure_1](Figure_1.png)
#
# The spread of revenue by method shows a slightly different story. Although email still reigned dominant as far as sales went, the Call method did not provide with as much revenue as the email and call combined.
#
# ![Figure_2](Figure_2.png)
#
# Also, if we look at the spread of data by revenue per sale in our boxplot, we see that per sale, the email and call was more lucrative.
#
# ![Figure_3](Figure_3.png)
#
# Looking at revenue over time by method, we see that Email started strong but gradually decreased in revenue over time, however, Email and Call combined had increasing revenue over time while Call alone stayed stagnant and even dipped a bit in the end of the timeframe.
#
# ![Figure_4](Figure_4.png)
#
# Based on these findings, I would recommend continuing the email method since it takes th least amout of resources and has the most amout of revenue generated and only including the call + email method, since this takes less time than just the Call method and reinforces sales in the long run while the email only method may be slowing in revenue. Also, with half the amount of sales and twice the amount of revenue, the Email + Call method definitely is more lucrative.
#
#
# ![Figure_5](Figure_5.png)
#
# ![Figure_6](Figure_6.png)
#
#
# Other insights:
# - newer customers tend to produce more revenue as shown in figure 5, so it may be wise to focus on that demographic
#
# - site visits seem resemble a normal curve with the average at 26, meaning site views up to this point seem to generate the most revenue. Could be something else to look into and keep an eye on.

# %% [markdown]
# ## ✅ When you have finished...
# -  Publish your Workspace using the option on the left
# -  Check the published version of your report:
# 	-  Can you see everything you want us to grade?
#     -  Are all the graphics visible?
# -  Review the grading rubric. Have you included everything that will be graded?
# -  Head back to the [Certification Dashboard](https://app.datacamp.com/certification) to submit your practical exam report and record your presentation
